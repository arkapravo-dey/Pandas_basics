# %% [markdown]
# <a href="https://colab.research.google.com/github/arkapravo-dey/Pandas_basics/blob/main/Starting_with_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Lets install Pandas in to our local environment

# %%
# !pip install pandas

# %% [markdown]
# **Getting started with Pandas Series
#
# A Series is a one-dimensional labeled array that can hold any data type (integers, strings, floating-point numbers, Python objects, etc.).
#
# > Add blockquote

# %%
import pandas as pd

# create a Pandas Series object
s = pd.Series([1,2,3,4,5])

# print the Series object
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# **Getting started with a pandas dataframe

# %%
# create a dictionary with some data
data = {'name': ['Alice', 'Bob', 'Charlie', 'David', 'Emily'],
        'age': [25, 32, 18, 47, 22],
        'country': ['USA', 'Canada', 'USA', 'Canada', 'USA']}

# create a Pandas DataFrame object from the dictionary
df = pd.DataFrame(data)

# print the DataFrame object
print(df)
# Out:
#       name  age country
# 0    Alice   25     USA
# 1      Bob   32  Canada
# 2  Charlie   18     USA
# 3    David   47  Canada
# 4    Emily   22     USA

# %%
# read Excel file into a Pandas DataFrame(some random file named test.xlsx that I had created in my local machine
#and uploaded to colab's local environment
df1 = pd.read_excel('/content/test.xlsx')

# print the DataFrame
print(df1)
# Out:
#   name  cgpa placement
# 0    A  9.82       YES
# 1    B  8.95       YES
# 2    C  9.31       YES
# 3    D  9.12        NO

# %%
import pandas as pd

# read CSV file into a Pandas DataFrame(again some random csv file called data.csv)
df = pd.read_csv('/content/data.csv')

# print the DataFrame
print(df)
# Out:
#     IQ  CGPA PLACEMENT
# 0   95  9.48       YES
# 1   91  9.12       YES
# 2  105  8.75        NO
# 3  110  9.98       YES

# %% [markdown]
# **Reading a csv file from a url

# %%
iris_data_url = 'https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv'

# %%
df2 = pd.read_csv(iris_data_url)

# %%
df2
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df3 = pd.read_csv('https://github.com/adrian-io/medical-cost-prediction/raw/main/insurance.csv')

# %%
df3
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df2
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# **Selecting specific rows and columns by loc function(by labels)
#
# ---

# %%
df2.loc[3:7,['sepal.length','variety']]
# Out:
#    sepal.length variety
# 3           4.6  Setosa
# 4           5.0  Setosa
# 5           5.4  Setosa
# 6           4.6  Setosa
# 7           5.0  Setosa

# %% [markdown]
# **Selecting rows and columns by iloc function(integer positions)

# %%
df2.iloc[1:11, [3,4]] #indices start from 0 and not one
# Out:
#     petal.width variety
# 1           0.2  Setosa
# 2           0.2  Setosa
# 3           0.2  Setosa
# 4           0.2  Setosa
# 5           0.4  Setosa
# 6           0.3  Setosa
# 7           0.2  Setosa
# 8           0.2  Setosa
# 9           0.1  Setosa
# 10          0.2  Setosa

# %%
df2.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %% [markdown]
# **Getting an overall idea about our dataset

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df2.describe() #this gives the summary statistics of the numerical columns
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df2.head()#gives the initial 5 rows
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df2.tail()#gives the ending 5 rows
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
df2.shape #dimensions
# Out:
# (150, 5)

# %%
df2['variety'].value_counts() #returns the count of each distinct element in variety column
# Out:
# variety
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %%
df2['variety'].unique() #returns the unique elements in "variety" as an array
# Out:
# array(['Setosa', 'Versicolor', 'Virginica'], dtype=object)

# %%
df2['sepal.length'].mean() #mean of all entries in "sepal.length"
# Out:
# 5.843333333333334

# %%
df2['sepal.length'].median() #median of all entries in "sepal.length"
# Out:
# 5.8

# %%
df2['petal.length'].std() #standard deviation of entries in "petal.length"
# Out:
# 1.7652982332594662

# %%
df2['petal.length'].var() #variance of entries in "petal.length"
# Out:
# 3.116277852348993

# %%
df2.isnull() #checks if there are empty entries, returns false if value is present
# Out:
#      sepal.length  sepal.width  petal.length  petal.width  variety
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %% [markdown]
# **Creating an dataframe to demonstrate how to fill in the empty values by the mean

# %%
import numpy as np
# create a sample dataframe with missing values  (We are creating a new dataframe as we didnt have any null values in ouroriginal dataframe)
df1 = pd.DataFrame({'A': [1, 2, np.nan, 4],
                   'B': [5, np.nan, 7, 8],
                   'C': [np.nan, 10, 11, 12]})

# replace missing values with column mean
df1.fillna(df1.mean(), inplace=False) #think of what  inplace=True will do

# display the dataframe with missing values replaced
print(df1)
# Out:
#      A    B     C
# 0  1.0  5.0   NaN
# 1  2.0  NaN  10.0
# 2  NaN  7.0  11.0
# 3  4.0  8.0  12.0

# %%
df1.isnull() #isnull true indicates that that entry is empty
# Out:
#        A      B      C
# 0  False  False   True
# 1  False   True  False
# 2   True  False  False
# 3  False  False  False

# %%
df1.fillna(df1.mean(), inplace=True) #replacing the empty entries by the mean
df1
# Out:
#           A         B     C
# 0  1.000000  5.000000  11.0
# 1  2.000000  6.666667  10.0
# 2  2.333333  7.000000  11.0
# 3  4.000000  8.000000  12.0

# %%
df1.sort_values('A',ascending = False) #sorting column 'A' is descending order(ascending is the default)
df1
# Out:
#           A         B     C
# 0  1.000000  5.000000  11.0
# 1  2.000000  6.666667  10.0
# 2  2.333333  7.000000  11.0
# 3  4.000000  8.000000  12.0

# %%
df1.sort_values('A',ascending = False)
# Out:
#           A         B     C
# 3  4.000000  8.000000  12.0
# 2  2.333333  7.000000  11.0
# 1  2.000000  6.666667  10.0
# 0  1.000000  5.000000  11.0

# %%
df1.rename(columns={'A': 'aa','B':'bb','C':'cc'}, inplace=True) #renaming the columns names to desired new names
df1
# Out:
#          aa        bb    cc
# 0  1.000000  5.000000  11.0
# 1  2.000000  6.666667  10.0
# 2  2.333333  7.000000  11.0
# 3  4.000000  8.000000  12.0

# %% [markdown]
# **Merging two dataframes by a common key

# %%
import pandas as pd

# Create first dataframe
df1 = pd.DataFrame({'key': ['A', 'B', 'C', 'D'],
                    'value': [1, 2, 3, 4]})

# Create second dataframe
df2 = pd.DataFrame({'key': ['B', 'D', 'E', 'F'],
                    'value': [5, 6, 7, 8]})

# Merge df1 and df2 on the 'key' column
merged_df = pd.merge(df1, df2, on='key')
merged_df
# Out:
#   key  value_x  value_y
# 0   B        2        5
# 1   D        4        6
